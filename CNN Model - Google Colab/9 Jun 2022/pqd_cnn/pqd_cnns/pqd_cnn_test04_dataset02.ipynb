# %%
## test04 adds one more Dense layer of 32 units
## between the Dense layer of 64 units and the output layer.
## Its activation algo is relu as well.
## Dataset used is pqd_dataset_02.

# %%
# Import dependencies
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers, models, utils, activations
from tensorflow.keras import optimizers, losses, metrics
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
training_dataset = utils.image_dataset_from_directory(
    directory='/content/drive/My Drive/pqd_dataset_02/training_set',
    labels='inferred',
    label_mode='categorical',
    color_mode='grayscale',
    image_size=(200, 200)
)
# Out:
# Found 3000 files belonging to 10 classes.

# %%
validation_dataset = utils.image_dataset_from_directory(
    directory='/content/drive/My Drive/pqd_dataset_02/validation_set',
    labels='inferred',
    label_mode='categorical',
    color_mode='grayscale',
    image_size=(200, 200)
)
# Out:
# Found 1000 files belonging to 10 classes.

# %%
cnn = models.Sequential()
# Add first convolution layer
cnn.add(layers.Conv2D(
    filters=32, 
    kernel_size=(5, 5), 
    padding='valid', 
    activation='relu', 
    input_shape=(200, 200, 1)
    )
)
cnn.add(layers.AvgPool2D(
    pool_size=(2, 2)
    )
)
# Add second convolution layer
cnn.add(layers.Conv2D(
    filters=48, 
    kernel_size=(3, 3), 
    padding='valid',
    activation='relu'
    )
)
cnn.add(layers.AvgPool2D(
    pool_size=(2, 2)
    )
)
# Add final convolution layer
cnn.add(layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    padding='valid',
    activation='relu'
    )
)
# Add flatten layer
cnn.add(layers.Flatten())
# Add Dense layer of 128 units
cnn.add(layers.Dense(
    units=128,
    activation='relu'
  )
)
# Add Dense layer of 64 units
cnn.add(layers.Dense(
    units=64,
    activation='relu'
  )
)
# Add Dense layer of 32 units
cnn.add(layers.Dense(
    units=32,
    activation='relu'
  )
)
# Add the final fully-connected layer
cnn.add(layers.Dense(
    units=10,
    activation='softmax'
    )
)

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 196, 196, 32)      832
#
#  average_pooling2d (AverageP  (None, 98, 98, 32)       0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 96, 96, 48)        13872
#
#  average_pooling2d_1 (Averag  (None, 48, 48, 48)       0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 64)        27712
#
#  flatten (Flatten)           (None, 135424)            0
#
#  dense (Dense)               (None, 128)               17334400
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 10)                330
#
# ...
# Total params: 17,387,482
# Trainable params: 17,387,482
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Configure the CNN for training
cnn.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Train the CNN for 10 epochs
cnn.fit(
    training_dataset,
    epochs=10,
    validation_data=validation_dataset
)
# Out:
# Epoch 1/10
# 94/94 [==============================] - 365s 4s/step - loss: 13.7806 - accuracy: 0.6977 - val_loss: 0.1913 - val_accuracy: 0.9540
# Epoch 2/10
# 94/94 [==============================] - 8s 85ms/step - loss: 0.1944 - accuracy: 0.9473 - val_loss: 0.1339 - val_accuracy: 0.9740
# Epoch 3/10
# 94/94 [==============================] - 8s 85ms/step - loss: 0.1043 - accuracy: 0.9693 - val_loss: 0.1094 - val_accuracy: 0.9660
# Epoch 4/10
# 94/94 [==============================] - 8s 84ms/step - loss: 0.0781 - accuracy: 0.9747 - val_loss: 0.1816 - val_accuracy: 0.9340
# Epoch 5/10
# 94/94 [==============================] - 9s 90ms/step - loss: 0.0659 - accuracy: 0.9770 - val_loss: 0.0779 - val_accuracy: 0.9730
# Epoch 6/10
# 94/94 [==============================] - 8s 85ms/step - loss: 0.0561 - accuracy: 0.9800 - val_loss: 0.0843 - val_accuracy: 0.9680
# Epoch 7/10
# ...

# %%
# Save the trained model
cnn.save('/content/drive/My Drive/saved_models/pqd_cnn_test04_dataset02_model')
cnn.save('/content/drive/My Drive/saved_models/pqd_cnn_test04_dataset02_model.h5')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/saved_models/pqd_cnn_test04_dataset02_model/assets
