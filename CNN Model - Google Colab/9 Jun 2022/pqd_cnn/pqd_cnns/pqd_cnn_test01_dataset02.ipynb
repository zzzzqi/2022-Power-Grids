# %%
## test01 follows the CNN structure used by the paper.
## Dataset used is pqd_dataset_02.

# %%
# Import dependencies
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers, models, utils, activations
from tensorflow.keras import optimizers, losses, metrics
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
training_dataset = utils.image_dataset_from_directory(
    directory='/content/drive/My Drive/pqd_dataset_02/training_set',
    labels='inferred',
    label_mode='categorical',
    color_mode='grayscale',
    image_size=(200, 200)
)
# Out:
# Found 3000 files belonging to 10 classes.

# %%
validation_dataset = utils.image_dataset_from_directory(
    directory='/content/drive/My Drive/pqd_dataset_02/validation_set',
    labels='inferred',
    label_mode='categorical',
    color_mode='grayscale',
    image_size=(200, 200)
)
# Out:
# Found 1000 files belonging to 10 classes.

# %%
cnn = models.Sequential()
# Add first convolution layer
cnn.add(layers.Conv2D(
    filters=32, 
    kernel_size=(5, 5), 
    padding='valid', 
    activation='relu', 
    input_shape=(200, 200, 1)
    )
)
cnn.add(layers.AvgPool2D(
    pool_size=(2, 2)
    )
)
# Add second convolution layer
cnn.add(layers.Conv2D(
    filters=48, 
    kernel_size=(3, 3), 
    padding='valid',
    activation='relu'
    )
)
cnn.add(layers.AvgPool2D(
    pool_size=(2, 2)
    )
)
# Add final convolution layer
cnn.add(layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    padding='valid',
    activation='relu'
    )
)
# Add fully-connected layer
cnn.add(layers.Flatten())
cnn.add(layers.Dense(
    units=10,
    activation='softmax'
    )
)

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 196, 196, 32)      832
#
#  average_pooling2d (AverageP  (None, 98, 98, 32)       0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 96, 96, 48)        13872
#
#  average_pooling2d_1 (Averag  (None, 48, 48, 48)       0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 64)        27712
#
#  flatten (Flatten)           (None, 135424)            0
#
#  dense (Dense)               (None, 10)                1354250
#
# =================================================================
# Total params: 1,396,666
# Trainable params: 1,396,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Configure the CNN for training
cnn.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Train the CNN for 10 epochs
cnn.fit(
    training_dataset,
    epochs=10,
    validation_data=validation_dataset
)
# Out:
# Epoch 1/10
# 94/94 [==============================] - 318s 3s/step - loss: 37.1585 - accuracy: 0.7270 - val_loss: 0.1250 - val_accuracy: 0.9630
# Epoch 2/10
# 94/94 [==============================] - 8s 81ms/step - loss: 0.1114 - accuracy: 0.9620 - val_loss: 0.0858 - val_accuracy: 0.9710
# Epoch 3/10
# 94/94 [==============================] - 8s 81ms/step - loss: 0.0993 - accuracy: 0.9683 - val_loss: 0.0848 - val_accuracy: 0.9780
# Epoch 4/10
# 94/94 [==============================] - 8s 82ms/step - loss: 0.0776 - accuracy: 0.9743 - val_loss: 0.1345 - val_accuracy: 0.9610
# Epoch 5/10
# 94/94 [==============================] - 8s 81ms/step - loss: 0.0803 - accuracy: 0.9710 - val_loss: 0.0820 - val_accuracy: 0.9720
# Epoch 6/10
# 94/94 [==============================] - 8s 82ms/step - loss: 0.0615 - accuracy: 0.9813 - val_loss: 0.1575 - val_accuracy: 0.9620
# Epoch 7/10
# 94/94 [==============================] - 8s 82ms/step - loss: 0.0520 - accuracy: 0.9813 - val_loss: 0.0829 - val_accuracy: 0.9810
# Epoch 8/10
# 94/94 [==============================] - 8s 82ms/step - loss: 0.0615 - accuracy: 0.9787 - val_loss: 0.0924 - val_accuracy: 0.9720
# Epoch 9/10
# 94/94 [==============================] - 8s 81ms/step - loss: 0.0718 - accuracy: 0.9770 - val_loss: 0.0968 - val_accuracy: 0.9690
# Epoch 10/10
# 94/94 [==============================] - 8s 82ms/step - loss: 0.0467 - accuracy: 0.9850 - val_loss: 0.0924 - val_accuracy: 0.9680

# %%
# Save the trained model
cnn.save('/content/drive/My Drive/saved_models/pqd_cnn_test01_dataset02_model')
cnn.save('/content/drive/My Drive/saved_models/pqd_cnn_test01_dataset02_model.h5')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/saved_models/pqd_cnn_test01_dataset02_model/assets
