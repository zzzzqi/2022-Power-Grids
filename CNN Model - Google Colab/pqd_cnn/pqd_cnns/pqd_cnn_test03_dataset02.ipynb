# %%
## test03 adds one more Dense layer of 64 units
## between the Dense layer of 128 units and the output layer.
## Its activation algo is relu as well.
## Dataset used is pqd_dataset_02.

# %%
# Import dependencies
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers, models, utils, activations
from tensorflow.keras import optimizers, losses, metrics
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
training_dataset = utils.image_dataset_from_directory(
    directory='/content/drive/My Drive/pqd_dataset_02/training_set',
    labels='inferred',
    label_mode='categorical',
    color_mode='grayscale',
    image_size=(200, 200)
)
# Out:
# Found 3000 files belonging to 10 classes.

# %%
validation_dataset = utils.image_dataset_from_directory(
    directory='/content/drive/My Drive/pqd_dataset_02/validation_set',
    labels='inferred',
    label_mode='categorical',
    color_mode='grayscale',
    image_size=(200, 200)
)
# Out:
# Found 1000 files belonging to 10 classes.

# %%
cnn = models.Sequential()
# Add first convolution layer
cnn.add(layers.Conv2D(
    filters=32, 
    kernel_size=(5, 5), 
    padding='valid', 
    activation='relu', 
    input_shape=(200, 200, 1)
    )
)
cnn.add(layers.AvgPool2D(
    pool_size=(2, 2)
    )
)
# Add second convolution layer
cnn.add(layers.Conv2D(
    filters=48, 
    kernel_size=(3, 3), 
    padding='valid',
    activation='relu'
    )
)
cnn.add(layers.AvgPool2D(
    pool_size=(2, 2)
    )
)
# Add final convolution layer
cnn.add(layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    padding='valid',
    activation='relu'
    )
)
# Add flatten layer
cnn.add(layers.Flatten())
# Add Dense layer of 128 units
cnn.add(layers.Dense(
    units=128,
    activation='relu'
  )
)
# Add Dense layer of 64 units
cnn.add(layers.Dense(
    units=64,
    activation='relu'
  )
)
# Add the final fully-connected layer
cnn.add(layers.Dense(
    units=10,
    activation='softmax'
    )
)

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 196, 196, 32)      832
#
#  average_pooling2d (AverageP  (None, 98, 98, 32)       0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 96, 96, 48)        13872
#
#  average_pooling2d_1 (Averag  (None, 48, 48, 48)       0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 64)        27712
#
#  flatten (Flatten)           (None, 135424)            0
#
#  dense (Dense)               (None, 128)               17334400
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 17,385,722
# Trainable params: 17,385,722
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Configure the CNN for training
cnn.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Train the CNN for 10 epochs
cnn.fit(
    training_dataset,
    epochs=10,
    validation_data=validation_dataset
)
# Out:
# Epoch 1/10
# 94/94 [==============================] - 322s 3s/step - loss: 15.4602 - accuracy: 0.7647 - val_loss: 0.2189 - val_accuracy: 0.9050
# Epoch 2/10
# 94/94 [==============================] - 8s 84ms/step - loss: 0.1267 - accuracy: 0.9587 - val_loss: 0.1376 - val_accuracy: 0.9520
# Epoch 3/10
# 94/94 [==============================] - 8s 84ms/step - loss: 0.0816 - accuracy: 0.9700 - val_loss: 0.0787 - val_accuracy: 0.9710
# Epoch 4/10
# 94/94 [==============================] - 8s 83ms/step - loss: 0.0780 - accuracy: 0.9723 - val_loss: 0.0665 - val_accuracy: 0.9710
# Epoch 5/10
# 94/94 [==============================] - 8s 84ms/step - loss: 0.0758 - accuracy: 0.9703 - val_loss: 0.1207 - val_accuracy: 0.9470
# Epoch 6/10
# 94/94 [==============================] - 8s 82ms/step - loss: 0.0647 - accuracy: 0.9743 - val_loss: 0.0583 - val_accuracy: 0.9770
# Epoch 7/10
# 94/94 [==============================] - 8s 82ms/step - loss: 0.0580 - accuracy: 0.9783 - val_loss: 0.0599 - val_accuracy: 0.9730
# Epoch 8/10
# 94/94 [==============================] - 8s 82ms/step - loss: 0.0440 - accuracy: 0.9797 - val_loss: 0.0668 - val_accuracy: 0.9780
# Epoch 9/10
# 94/94 [==============================] - 8s 84ms/step - loss: 0.0432 - accuracy: 0.9830 - val_loss: 0.0752 - val_accuracy: 0.9670
# Epoch 10/10
# 94/94 [==============================] - 9s 94ms/step - loss: 0.0398 - accuracy: 0.9837 - val_loss: 0.1143 - val_accuracy: 0.9660

# %%
# Save the trained model
cnn.save('/content/drive/My Drive/saved_models/pqd_cnn_test03_dataset02_model')
cnn.save('/content/drive/My Drive/saved_models/pqd_cnn_test03_dataset02_model.h5')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/saved_models/pqd_cnn_test03_dataset02_model/assets
