# %%
# Import dependencies
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, layers, models, utils, activations
from tensorflow.keras import optimizers, losses, metrics
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_dataset = utils.image_dataset_from_directory(
    directory='/content/drive/My Drive/pqd_dataset/training_set',
    labels='inferred',
    label_mode='categorical',
    color_mode='grayscale',
    image_size=(200, 200)
)
# Out:
# Found 3200 files belonging to 10 classes.

# %%
test_dataset = utils.image_dataset_from_directory(
    directory='/content/drive/My Drive/pqd_dataset/test_set',
    labels='inferred',
    label_mode='categorical',
    color_mode='grayscale',
    image_size=(200, 200)
)
# Out:
# Found 800 files belonging to 10 classes.

# %%
cnn = models.Sequential()
# Add first convolution layer
cnn.add(layers.Conv2D(
    filters=32, 
    kernel_size=(5, 5), 
    padding='valid', 
    activation='relu', 
    input_shape=(200, 200, 1)
    )
)
cnn.add(layers.AvgPool2D(
    pool_size=(2, 2)
    )
)
# Add second convolution layer
cnn.add(layers.Conv2D(
    filters=48, 
    kernel_size=(3, 3), 
    padding='valid',
    activation='relu'
    )
)
cnn.add(layers.AvgPool2D(
    pool_size=(2, 2)
    )
)
# Add final convolution layer
cnn.add(layers.Conv2D(
    filters=64, 
    kernel_size=(3, 3), 
    padding='valid',
    activation='relu'
    )
)
# Add fully-connected layer
cnn.add(layers.Flatten())
cnn.add(layers.Dense(
    units=10,
    activation='softmax'
    )
)

# %%
cnn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 196, 196, 32)      832
#
#  average_pooling2d_4 (Averag  (None, 98, 98, 32)       0
#  ePooling2D)
#
#  conv2d_7 (Conv2D)           (None, 96, 96, 48)        13872
#
#  average_pooling2d_5 (Averag  (None, 48, 48, 48)       0
#  ePooling2D)
#
#  conv2d_8 (Conv2D)           (None, 46, 46, 64)        27712
#
#  flatten_2 (Flatten)         (None, 135424)            0
#
#  dense_2 (Dense)             (None, 10)                1354250
#
# ...
# Total params: 1,396,666
# Trainable params: 1,396,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Configure the CNN for training
cnn.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Train the CNN for 10 epochs
cnn.fit(
    train_dataset,
    epochs=10,
    validation_data=test_dataset
)
# Out:
# Epoch 1/10
# 100/100 [==============================] - 522s 5s/step - loss: 29.7426 - accuracy: 0.7781 - val_loss: 0.0802 - val_accuracy: 0.9825
# Epoch 2/10
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0600 - accuracy: 0.9816 - val_loss: 0.0572 - val_accuracy: 0.9825
# Epoch 3/10
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0311 - accuracy: 0.9887 - val_loss: 0.0683 - val_accuracy: 0.9837
# Epoch 4/10
# 100/100 [==============================] - 8s 80ms/step - loss: 0.0245 - accuracy: 0.9906 - val_loss: 0.0668 - val_accuracy: 0.9825
# Epoch 5/10
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0746 - accuracy: 0.9816 - val_loss: 0.1318 - val_accuracy: 0.9650
# Epoch 6/10
# 100/100 [==============================] - 8s 79ms/step - loss: 0.0420 - accuracy: 0.9850 - val_loss: 0.0922 - val_accuracy: 0.9712
# Epoch 7/10
# ...

# %%
# Save the trained model
cnn.save('/content/drive/My Drive/saved_models/pqd_cnn_test00_model')
cnn.save('/content/drive/My Drive/saved_models/pqd_cnn_test00_model.h5')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/saved_models/pqd_cnn_test00_model/assets
