# %%
import numpy as np
import pandas as pd
import random as rd
from sklearn.decomposition import PCA
from sklearn import preprocessing
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("test_cnnoutputs.csv", header=0, usecols=range(14, 74))
df = df.dropna()

# %%
df.head()
# Out:
#     Vab_sag  Vab_swell  Vab_inter  Vab_flicker  Vab_harmonic   Vab_osc  \
# 0  0.371127   0.194666   0.684682     0.639327      0.545217  0.223334
# 1  0.548331   0.334701   0.186409     0.241561      0.079449  0.208572
# 2  0.024478   0.268165   0.219049     0.440510      0.904665  0.583063
# 3  0.612386   0.567180   0.173504     0.751767      0.680181  0.948995
# 4  0.646433   0.112410   0.825610     0.815759      0.272714  0.706462
#
#    Vab_spike  Vab_sag_har  Vab_swell_har  Vab_swell_har.1  ...    Ic_sag  \
# 0   0.624122     0.731550       0.862828         0.189666  ...  0.888515
# 1   0.669299     0.939155       0.698457         0.448072  ...  0.727131
# 2   0.031693     0.661249       0.027490         0.457145  ...  0.721809
# 3   0.763491     0.178871       0.859549         0.457661  ...  0.441962
# 4   0.794286     0.359866       0.871827         0.346437  ...  0.431041
#
#    Ic_swell  Ic_inter  Ic_flicker  Ic_harmonic    Ic_osc  Ic_spike  \
# 0  0.724640  0.020325    0.512331     0.363985  0.701859  0.487339
# 1  0.754084  0.962850    0.399715     0.303269  0.968757  0.685985
# 2  0.267406  0.343909    0.253805     0.128656  0.511291  0.948398
# 3  0.599853  0.392072    0.422444     0.158234  0.411408  0.358755
# 4  0.181784  0.698153    0.355014     0.639014  0.977626  0.691312
#
#    Ic_sag_har  Ic_swell_har  Ic_swell_har.1
# 0    0.980476      0.521919        0.453062
# 1    0.046000      0.948517        0.147573
# 2    0.219411      0.904304        0.207251
# 3    0.711106      0.953200        0.228819
# 4    0.219484      0.827402        0.417812
#
# [5 rows x 60 columns]

# %%
vab_sag = df['Vab_sag'].to_numpy()
vab_swell = df['Vab_swell'].to_numpy()
# vab_sag
print(vab_sag)
print(vab_swell)
# Out:
# [0.37112747 0.54833056 0.02447819 0.6123858  0.64643262 0.19311199
#  0.61913169 0.28557425 0.04193627 0.32826596]
# [0.19466642 0.33470124 0.26816539 0.56717997 0.11240966 0.8193857
#  0.91843576 0.28557425 0.21088328 0.49839037]

# %%
plt.xlim(0,1)
plt.ylim(0,1)
plt.scatter(vab_sag, vab_swell)
plt.show()
